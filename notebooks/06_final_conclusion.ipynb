# %% [markdown]
# ### 用户侧结论
#
# 年龄6、1 → 高CTR
#
# pvalue中低 → 更容易点击
#
# NaN用户不能删除

# %% [markdown]
# ### 广告侧结论
#
# customer差异大
#
# campaign影响大
#
# 价格负相关CTR

# %% [markdown]
# ## 广告投放优化建议
#
# 1. 用户定向优化：
#    - 优先投放年龄层6和1的用户
#    - 针对高消费用户优化广告内容而非增加曝光
#
# 2. 广告策略优化：
#    - 分析高CTR广告主和campaign的成功经验并进行复用
#    - 持续优化低CTR广告策略
#
# 3. 商品策略：
#    - 对高价商品加强内容营销
#    - 低价商品可作为引流入口
